# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
training_path = ".\\Task3\\Yale-FaceA\\trainingset\\"
test_path = ".\\Task3\\Yale-FaceA\\testset\\"

# %%
import os

def loadImgs(path: str, h=195, w=231):
    file_list = os.listdir(path)
    imgs = []
    for file in file_list:
        img = cv2.imread(path + file, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (h, w))
        vector = img.reshape(h * w, 1)
        imgs.append(vector)
    imgs = np.array(imgs)
    imgs = imgs.reshape(h, w)
    return np.mat(imgs).T

# %%
h = 195
w = 231

training_set = loadImgs(training_path, h, w)
test_set = loadImgs(test_path, h, w)

print(training_set.shape)
print(test_set.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-cf57682ed211> in <module>
#       2 w = 231
#       3
# ----> 4 training_set = loadImgs(training_path, h, w)
#       5 test_set = loadImgs(test_path, h, w)
#       6
#
# <ipython-input-17-35006d12c603> in loadImgs(path, h, w)
#      10         imgs.append(vector)
#      11     imgs = np.array(imgs)
# ---> 12     imgs = imgs.reshape(h, w)
#      13     return np.mat(imgs).T
#
# ValueError: cannot reshape array of size 6081075 into shape (195,231)

# %%
def recognizeEigen(data, k: int):
    # Get the mean image:
    meanImg = data.mean(axis=1)
    # Normalize and get the deviation matrix:
    devi = data - meanImg  
    # Calculate feature vector and feature value:
    vals, vects = np.linalg.eig(np.mat(devi.T * devi))
    # Get the index of the k biggest features:
    valsIndex = np.argsort(-vals)
    valsIndex = valsIndex[:k]
    # eigenvector of convariance matrix:
    conVects = devi * vects[:, valsIndex]
    
    return meanImg, conVects, devi

# %%
meanImg, conVects, devi = recognizeEigen(training_set, k=10)
print("meanImg:", meanImg.shape)
print("conVects:", conVects.shape)
print("devi:", devi.shape)
plt.imshow(np.uint8(meanImg.reshape(h, w)), cmap="gray")
# Out:
# meanImg: (45045, 1)
# conVects: (45045, 10)
# devi: (45045, 135)
